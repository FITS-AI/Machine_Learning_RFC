# %%
import numpy as np
import pandas as pd

# %%
nutcomp = "/content/drive/MyDrive/foodie.csv"
nutcomp_df = pd.read_csv(nutcomp)
nutcomp_df.head()
# Out:
#    NDB_No       Short_Description  Water_In_Grams  Energy_In_Kilogram_Calorie  \
# 0    1001        BUTTER,WITH SALT           15.87                         717
# 1    1002  BUTTER,WHIPPED,W/ SALT           16.72                         718
# 2    1003    BUTTER OIL,ANHYDROUS            0.24                         876
# 3    1004             CHEESE,BLUE           42.41                         353
# 4    1005            CHEESE,BRICK           41.11                         371
#
#    Protein_In_Grams  Lipid_Tot_In_Grams  Ash_In_Grams  Carbohydrate_In_Grams  \
# 0              0.85               81.11          2.11                   0.06
# 1              0.49               78.30          1.62                   2.87
# 2              0.28               99.48          0.00                   0.00
# 3             21.40               28.74          5.11                   2.34
# 4             23.24               29.68          3.18                   2.79
#
# ...

# %%
# Menemukan Missing Value
nutcomp_df.isnull().sum()
# Out:
# NDB_No                                      0
# Short_Description                           0
# Water_In_Grams                              1
# Energy_In_Kilogram_Calorie                  0
# Protein_In_Grams                            0
# Lipid_Tot_In_Grams                          0
# Ash_In_Grams                              325
# Carbohydrate_In_Grams                       0
# Fiber_TD_In_Grams                         594
# Sugar_Tot_In_Grams                       1832
# Calcium_In_Miligrams                      348
# Iron_In_Miligrams                         144
# Magnesium_In_Miligrams                    739
# Phosphorus_In_Miligrams                   579
# Potassium_In_Miligrams                    426
# Sodium_In_Miligrams                        83
# Zinc_In_Miligrams                         706
# Copper_In_Miligrams                      1257
# Manganese_In_Miligrams                   2160
# Selenium_In_Micrograms                   1700
# ...

# %%
# Mengisi nilai kosong pada kolom 'sugar' dengan 0
nutcomp_df_cleaned['Sugar_Tot_In_Grams'] = nutcomp_df['Sugar_Tot_In_Grams'].fillna(0)
nutcomp_df_cleaned['Fiber_TD_In_Grams'] = nutcomp_df['Fiber_TD_In_Grams'].fillna(0)

# Menampilkan DataFrame
print(nutcomp_df_cleaned)
# Out:
#       NDB_No           Short_Description  Energy_In_Kilogram_Calorie  \
# 0       1001            BUTTER,WITH SALT                         717
# 1       1002      BUTTER,WHIPPED,W/ SALT                         718
# 2       1003        BUTTER OIL,ANHYDROUS                         876
# 3       1004                 CHEESE,BLUE                         353
# 4       1005                CHEESE,BRICK                         371
# ...      ...                         ...                         ...
# 8785   83110             MACKEREL,SALTED                         305
# 8786   90240  SCALLOP,(BAY&SEA),CKD,STMD                         111
# 8787   90480                  SYRUP,CANE                         269
# 8788   90560                   SNAIL,RAW                          90
# 8789   93600            TURTLE,GREEN,RAW                          89
#
#       Protein_In_Grams  Lipid_Tot_In_Grams  Carbohydrate_In_Grams  \
# 0                 0.85               81.11                   0.06
# ...

# %%
# Menampilkan DataFrame yang sudah dibersihkan
nutcomp_df_cleaned.head()
# Out:
#    NDB_No       Short_Description  Energy_In_Kilogram_Calorie  \
# 0    1001        BUTTER,WITH SALT                         717
# 1    1002  BUTTER,WHIPPED,W/ SALT                         718
# 2    1003    BUTTER OIL,ANHYDROUS                         876
# 3    1004             CHEESE,BLUE                         353
# 4    1005            CHEESE,BRICK                         371
#
#    Protein_In_Grams  Lipid_Tot_In_Grams  Carbohydrate_In_Grams  \
# 0              0.85               81.11                   0.06
# 1              0.49               78.30                   2.87
# 2              0.28               99.48                   0.00
# 3             21.40               28.74                   2.34
# 4             23.24               29.68                   2.79
#
#    Sugar_Tot_In_Grams  Fiber_TD_In_Grams
# 0                0.06                0.0
# 1                0.06                0.0
# 2                0.00                0.0
# 3                0.50                0.0
# ...

# %%
# Mengubah nama kolom pada DataFrame
nutcomp_df_cleaned = nutcomp_df_cleaned.rename(columns={
    'NDB_No': 'food_id',
    'Short_Description': 'composition',
    'Energy_In_Kilogram_Calorie': 'calories',
    'Protein_In_Grams': 'protein',
    'Lipid_Tot_In_Grams': 'Fat',
    'Carbohydrate_In_Grams': 'carbohydrate',
    'Sugar_Tot_In_Grams': 'sugar',
    'Fiber_TD_In_Grams': 'fiber'
})

# Menampilkan DataFrame dengan nama kolom baru
nutcomp_df_cleaned.head()
# Out:
#    food_id             composition  calories  protein    Fat  carbohydrate  \
# 0     1001        BUTTER,WITH SALT       717     0.85  81.11          0.06
# 1     1002  BUTTER,WHIPPED,W/ SALT       718     0.49  78.30          2.87
# 2     1003    BUTTER OIL,ANHYDROUS       876     0.28  99.48          0.00
# 3     1004             CHEESE,BLUE       353    21.40  28.74          2.34
# 4     1005            CHEESE,BRICK       371    23.24  29.68          2.79
#
#    sugar  fiber
# 0   0.06    0.0
# 1   0.06    0.0
# 2   0.00    0.0
# 3   0.50    0.0
# 4   0.51    0.0

# %%
nutcomp_df_cleaned.to_csv("new_nutcomp.csv", index=False)
